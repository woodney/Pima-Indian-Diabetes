# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import math

# %%
from numpy import NaN, NAN, nan

# %%
df1 = pd.read_csv("diabetes.csv")

# %%
list(df1.columns.values)
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
# 0. Compute the mean and standard deviation and remove unnecessary zeros before computing
NaN == True
NaN == False
NaN == 0
# Out:
# False

# %%
print(pd.isnull(NaN))
print(pd.isnull(nan))
print(pd.isnull(NAN))
# Out:
# True
# True
# True

# %%
df1[df1 == 0] = np.nan

# %%
g = df1["Glucose"]
bl = df1["BloodPressure"]
s = df1["SkinThickness"]
i = df1["Insulin"]
bm = df1["BMI"]
d = df1['DiabetesPedigreeFunction']
a = df1['Age']

# %%
zero1 = pd.DataFrame({
    'Glucose': [np.nanmean(g, axis = 0)], 'BloodPressure': [np.nanmean(bl, axis = 0)], 'SkinThickness': [np.nanmean(s, axis = 0)], 'Insulin': [np.nanmean(i, axis = 0)], 'BMI': [np.nanmean(bm, axis = 0)]
})
zero1
# Out:
#       Glucose  BloodPressure  SkinThickness     Insulin        BMI
# 0  121.686763      72.405184       29.15342  155.548223  32.457464

# %%
zero2 = pd.DataFrame({
    'Glucose': [np.nanstd(g, axis = 0)], 'BloodPressure': [np.nanstd(bl, axis = 0)], 'SkinThickness': [np.nanstd(s, axis = 0)], 'Insulin': [np.nanstd(i, axis = 0)], 'BMI': [np.nanstd(bm, axis = 0)]
})
zero2
# Out:
#      Glucose  BloodPressure  SkinThickness     Insulin       BMI
# 0  30.515624      12.373709      10.467295  118.625029  6.920413

# %%
#1 Compute the covariance matrix
meanX1 = np.nanmean(g, axis = 0)
meanY1 = np.nanmean(bl, axis = 0)
meanX2 = np.nanmean(g, axis = 0)
meanY2 = np.nanmean(s, axis = 0)
meanX3 = np.nanmean(g, axis = 0)
meanY3 = np.nanmean(i, axis = 0)
meanX4 = np.nanmean(g, axis = 0)
meanY4 = np.nanmean(bm, axis = 0)
meanX5 = np.nanmean(bl, axis = 0)
meanY5 = np.nanmean(s, axis = 0)
meanX6 = np.nanmean(bl, axis = 0)
meanY6 = np.nanmean(i, axis = 0)
meanX7 = np.nanmean(bl, axis = 0)
meanY7 = np.nanmean(bm,axis = 0)
meanX8 = np.nanmean(s, axis = 0)
meanY8 = np.nanmean(i, axis = 0)
meanX9 = np.nanmean(s, axis = 0)
meanY9 = np.nanmean(bm, axis = 0)
meanX10 = np.nanmean(i, axis = 0)
meanY10 = np.nanmean(bm, axis = 0)

# %%
stdX1 = np.nanstd(g, axis = 0)
stdY1 = np.nanstd(bl, axis = 0)
stdX2 = np.nanstd(g, axis = 0)
stdY2 = np.nanstd(s, axis = 0)
stdX3 = np.nanstd(g, axis = 0)
stdY3 = np.nanstd(i, axis = 0)
stdX4 = np.nanstd(g, axis = 0)
stdY4 = np.nanstd(bm, axis = 0)
stdX5 = np.nanstd(bl, axis = 0)
stdY5 = np.nanstd(s, axis = 0)
stdX6 = np.nanstd(bl, axis = 0)
stdY6 = np.nanstd(i, axis = 0)
stdX7 = np.nanstd(bl, axis = 0)
stdY7 = np.nanstd(bm,axis = 0)
stdX8 = np.nanstd(s, axis = 0)
stdY8 = np.nanstd(i, axis = 0)
stdX9 = np.nanstd(s, axis = 0)
stdY9 = np.nanstd(bm, axis = 0)
stdX10 = np.nanstd(i, axis = 0)
stdY10 = np.nanstd(bm, axis = 0)

# %%
XY1 = list(zip(g,bl))
XY2 = list(zip(g,s))
XY3 = list(zip(g,i))
XY4 = list(zip(g,bm))
XY5 = list(zip(bl,s))
XY6 = list(zip(bl,i))
XY7 = list(zip(bl,bm))
XY8 = list(zip(s,i))
XY9 = list(zip(s,bm))
XY10 = list(zip(i,bm))

# %%
cov1 = lambda x, y, z: (x*y).sum()/len(z)
print(cov1(meanX1,meanY1,XY1))
cov2 = lambda x, y, z: (x*y).sum()/len(z)
print(cov2(meanX2,meanY2,XY2))
cov3 = lambda x, y, z: (x*y).sum()/len(z)
print(cov3(meanX3,meanY3,XY3))
cov4 = lambda x, y, z: (x*y).sum()/len(z)
print(cov4(meanX4,meanY4,XY4))
cov5 = lambda x, y, z: (x*y).sum()/len(z)
print(cov5(meanX5,meanY5,XY5))
cov6 = lambda x, y, z: (x*y).sum()/len(z)
print(cov6(meanX6,meanY6,XY6))
cov7 = lambda x, y, z: (x*y).sum()/len(z)
print(cov7(meanX7,meanY7,XY7))
cov8 = lambda x, y, z: (x*y).sum()/len(z)
print(cov8(meanX8,meanY8,XY8))
cov9 = lambda x, y, z: (x*y).sum()/len(z)
print(cov9(meanX9,meanY9,XY9))
cov10 = lambda x, y, z: (x*y).sum()/len(z)
print(cov10(meanX10,meanY10,XY10))
# Out:
# 11.472333946082815
# 4.619251633122004
# 24.64604134822967
# 5.142765211320596
# 2.7485139517920683
# 14.664710624623446
# 3.0600112435425344
# 5.904638831158067
# 1.2320912205429544
# 6.573829177989357

# %%
#The covariance values listen above show that all 10 pairs of the 5 attributes have a positive value meaning that all 10 pairs are positively related

# %%
#2Create a scatter plot for attributes 3 and 6, and a second scatter plot for 2 and 7
import matplotlib.pyplot as plt

# %%
plt.plot(df1['BloodPressure'],df1['BMI'], 'o')

# %%
#The scatter plot above show that the two attributes have a positive correlation and have a strong relationship between 60 and 90 
d = df1["DiabetesPedigreeFunction"]

# %%
plt.scatter(g,d, label = 'scatter1')

# %%
#The scatter plot above show that the two attributes have a weak positive correlation

# %%
#3 Create histograms for 2, 3, and 6 and its instances for classes 0 and 1

# %%
df = pd.read_csv("diabetes.csv")

# %%
newg = df['Glucose']

# %%
plt.hist(newg, bins = 'auto')
plt.title("Histogram of Glucose Levels")
plt.show()

# %%
hist1 = df[df['Outcome'] == 0]['Glucose']
hist2 = df[df['Outcome'] == 1]['Glucose']

# %%
plt.hist(hist1, bins = 'auto')
plt.title("Histogram of Glucose Levels without Diabetes")
plt.show()

# %%
plt.hist(hist2, bins = 'auto')
plt.title("Histogram of Glucose Levels with Diabetes")
plt.show()

# %%
#The histrograms above show the glucose levels of the Prima Indians as a whole, then those without diabetes and those with diabetes.
#This data shows that there is a strong correlation between the concentration of glucose and the chance of having diabetes

# %%
newbl = df['BloodPressure']

# %%
plt.hist(newbl, bins = 'auto')
plt.title("Histogram of BloodPressure")
plt.show()

# %%
hist3 = df[df['Outcome'] == 0]['BloodPressure']
hist4 = df[df['Outcome'] == 1]['BloodPressure']

# %%
plt.hist(hist3, bins = 'auto')
plt.title("Histogram of BloodPressure without Diabetes")
plt.show()

# %%
plt.hist(hist4, bins = 'auto')
plt.title("Histogram of BloodPressure with Diabetes")
plt.show()

# %%
#The histograms above show the BloodPressure of the Prima Indians as a whole, then those with diabetes and those without diabetes
#This shows that there is a positive correlation between BloodPressure and the chances of getting diabetes

# %%
newbm = df['BMI']

# %%
plt.hist(newbm, bins = 'auto')
plt.title("Histogram of BMI")
plt.show()

# %%
hist5 = df[df['Outcome'] == 0]['BMI']
hist6 = df[df['Outcome'] == 1]['BMI']

# %%
plt.hist(hist5, bins = 'auto')
plt.title("Histogram of BMI without Diabetes")
plt.show()

# %%
plt.hist(hist6, bins = 'auto')
plt.title("Histogram of BMI with Diabetes")
plt.show()

# %%
#The histograms above depics the BMI of Prima Indians as a whole, then those without diabetes and those with diabetes
#The histogram shows that those with lower BMI have a greater chance of getting diabetes

# %%
#4 Create boxplots for attributes 2, 7, and 8. Then create a boxplot for the instances of the two classes for each attribute

# %%
plt.boxplot(g.dropna())
plt.title("Boxplot of Glucose Levels")
# Out:
# Text(0.5,1,'Boxplot of Glucose Levels')

# %%
plot1 = df[df['Outcome'] == 0]['Glucose']
plot2 = df[df['Outcome'] == 1]['Glucose']

# %%
plt.boxplot(plot1)
plt.title("Boxplot of Glucose Levels without Diabetes")
# Out:
# Text(0.5,1,'Boxplot of Glucose Levels without Diabetes')

# %%
plt.boxplot(plot2)
plt.title("Boxplot of Glucose Levels with Diabetes")
# Out:
# Text(0.5,1,'Boxplot of Glucose Levels with Diabetes')

# %%
plt.boxplot(d.dropna())
plt.title("Boxplot of DiabetesPedigreeFunction")
# Out:
# Text(0.5,1,'Boxplot of DiabetesPedigreeFunction')

# %%
plot3 = df[df['Outcome'] == 0]['DiabetesPedigreeFunction']
plot4 = df[df['Outcome'] == 1]['DiabetesPedigreeFunction']

# %%
plt.boxplot(plot3)
plt.title("Boxplot of DiabetesPedigreeFunction without Diabetes")
# Out:
# Text(0.5,1,'Boxplot of DiabetesPedigreeFunction without Diabetes')

# %%
plt.boxplot(plot4)
plt.title("Boxplot of DiabetesPedigreeFunction with Diabetes")
# Out:
# Text(0.5,1,'Boxplot of DiabetesPedigreeFunction with Diabetes')

# %%
plt.boxplot(a.dropna())
plt.title("Boxplot of Age")
# Out:
# Text(0.5,1,'Boxplot of Age')

# %%
plot5 = df[df['Outcome'] == 0]['Age']
plot6 = df[df['Outcome'] == 1]['Age']

# %%
plt.boxplot(plot5)
plt.title("Boxplot of Age without Diabetes")
# Out:
# Text(0.5,1,'Boxplot of Age without Diabetes')

# %%
plt.boxplot(plot6)
plt.title("Boxplot of Age with Diabetes")
# Out:
# Text(0.5,1,'Boxplot of Age with Diabetes')

# %%
#The nine boxplots above show the attributes 2,7, and 8 and its instances with classes 0 and 1
#For attribute 2, Glucose, the boxplot show that those with diabetes normally have glucose levels higher than average
#For attribute 7, DiabetesPedigreeFunction, the boxplot shows that those with diabetes are more likely to have family members with diabetes
#For attribute 8, Age, the boxplot shows that those that are diagnosed with diabetes are older than the average person

# %%
#5 Create supervised scatter plots for all pairs of attribute 2-6. Then create two 3D-scatterplots of 2,3,6 and 2,4,6

# %%
plt.scatter(g,bl, marker = 'o')
plt.title("Scatter Plot of Glucose and BloodPressure")
# Out:
# Text(0.5,1,'Scatter Plot of Glucose and BloodPressure')

# %%
plt.scatter(g,s)
plt.title("Scatter Plot of Glucose and SkinThickness")
# Out:
# Text(0.5,1,'Scatter Plot of Glucose and SkinThickness')

# %%
plt.scatter(g,i)
plt.title("Scatter Plot of Glucose and Insulin")
# Out:
# Text(0.5,1,'Scatter Plot of Glucose and Insulin')

# %%
plt.scatter(g,bm)
plt.title("Scatter Plot of Glucose and BMI")
# Out:
# Text(0.5,1,'Scatter Plot of Glucose and BMI')

# %%
plt.scatter(bl,s)
plt.title("Scatter Plot of BloodPressure and SkinThickness")
# Out:
# Text(0.5,1,'Scatter Plot of BloodPressure and SkinThickness')

# %%
plt.scatter(bl,i)
plt.title("Scatter Plot of BloodPressure and Insulin")
# Out:
# Text(0.5,1,'Scatter Plot of BloodPressure and Insulin')

# %%
plt.scatter(bl,bm)
plt.title("Scatter Plot of BloodPressure and BMI")
# Out:
# Text(0.5,1,'Scatter Plot of BloodPressure and BMI')

# %%
plt.scatter(s,i)
plt.title("Scatter Plot of SkinThickness and Insulin")
# Out:
# Text(0.5,1,'Scatter Plot of SkinThickness and Insulin')

# %%
plt.scatter(s,bm)
plt.title("Scatter Plot of SkinThickness and BMI")
# Out:
# Text(0.5,1,'Scatter Plot of SkinThickness and BMI')

# %%
plt.scatter(i,bm)
plt.title("Scatter Plot of Insulin and BMI")
# Out:
# Text(0.5,1,'Scatter Plot of Insulin and BMI')

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(g,bl,bm, c = 'r',marker='o')
ax.set_xlabel('Glucose')
ax.set_ylabel('BloodPressure')
ax.set_zlabel('BMI')
# Out:
# Text(0.5,0,'BMI')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(g,s,bm, c = 'g', marker='^')
ax.set_xlabel('Glucose')
ax.set_ylabel('SkinThickness')
ax.set_zlabel('BMI')
# Out:
# Text(0.5,0,'BMI')

# %%
#The scatter plots above shows the trend of the pairs of attributes 2-6 and a 3D scatter plot of 2,3,6 and 2,4,6.
#What I interpret from the scatter plots is the positive correlation of the two attributes and that there is a trend among all of the pairs
#Also the 3D scatter plots shows a little more information of the relationship between 3 attributes and which attribute have a stronger positive relationship with diabetes

# %%
#6 Create a star plot for the first 10 instances of class 0 and 1 for attributes 1,2,3,8 in the cleaned dataset

# %%
df2 = pd.read_csv("diabetes_cleaned.csv")

# %%
df2['Pregnancies0'] = df2[df2['Outcome'] == 0]['Pregnancies']
df2['Glucose0'] = df2[df2['Outcome'] == 0]['Glucose']
df2['BloodPressure0'] = df2[df2['Outcome'] == 0]['BloodPressure']
df2['Age0'] = df2[df2['Outcome'] == 0]['Age']
star0 = df2[df2['Outcome'] == 0]
star0.head(10)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1             1       85             66             29      156  26.6
# 3             1       89             66             23       94  28.1
# 5             5      116             74             29      156  25.6
# 7            10      115             72             29      156  35.3
# 10            4      110             92             29      156  37.6
# 12           10      139             80             29      156  27.1
# 18            1      103             30             38       83  43.3
# 20            3      126             88             41      235  39.3
# 21            8       99             84             29      156  35.4
# 27            1       97             66             15      140  23.2
#
#     Diabetes  Age  Outcome  Pregnancies0  Glucose0  BloodPressure0  Age0
# 1      0.351   31        0           1.0      85.0            66.0  31.0
# ...

# %%
labels=np.array(['Pregnancies0', 'Glucose0', 'BloodPressure0', 'Age0'])
stats=df2.loc[386,labels].values

# %%
labels=np.array(['Pregnancies0', 'Glucose0', 'BloodPressure0', 'Age0'])
stats=df2.loc[1,labels].values
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, stats, 'o-', linewidth=2)
ax.fill(angles, stats, alpha=0.25)
ax.set_thetagrids(angles * 180/np.pi, labels)
ax.set_title([df2.loc[386,"Outcome"]])
ax.grid(True)

# %%
df2['Pregnancies1'] = df2[df2['Outcome'] == 1]['Pregnancies']
df2['Glucose1'] = df2[df2['Outcome'] == 1]['Glucose']
df2['BloodPressure1'] = df2[df2['Outcome'] == 1]['BloodPressure']
df2['Age1'] = df2[df2['Outcome'] == 1]['Age']
star1 = df2[df2['Outcome'] == 1]
star1.head(10)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35      156  33.6
# 2             8      183             64             29      156  23.3
# 4             0      137             40             35      168  43.1
# 6             3       78             50             32       88  31.0
# 8             2      197             70             45      543  30.5
# 9             8      125             96             29      156  32.0
# 11           10      168             74             29      156  38.0
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
# 15            7      100             72             29      156  30.0
#
#     Diabetes  Age  Outcome  Pregnancies0  Glucose0  BloodPressure0  Age0  \
# 0      0.627   50        1           NaN       NaN             NaN   NaN
# ...

# %%
labels=np.array(['Pregnancies1', 'Glucose1', 'BloodPressure1', 'Age1'])
stats=df2.loc[386,labels].values

# %%
labels=np.array(['Pregnancies1', 'Glucose1', 'BloodPressure1', 'Age1'])
stats=df2.loc[1,labels].values
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, stats, 'o-', linewidth=2)
ax.fill(angles, stats, alpha=0.25)
ax.set_thetagrids(angles * 180/np.pi, labels)
ax.set_title([df2.loc[386,"Outcome"]])
ax.grid(True)
# Out:
# C:\Users\woodn\Anaconda3\lib\site-packages\matplotlib\projections\polar.py:67: RuntimeWarning: invalid value encountered in less
#   mask = r < 0

# %%
#7 Fit a linear model

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
df2 = pd.read_csv("diabetes_cleaned.csv")

# %%
X = df2.drop('Outcome', axis = 1)
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.fit(X,df2.Outcome)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pd.DataFrame(list(zip(X.columns, lm.coef_)), columns = ['features', 'estimatedCoefficients'])
# Out:
#                    features  estimatedCoefficients
# 0               Pregnancies               0.020703
# 1                   Glucose               0.006465
# 2             BloodPressure              -0.001158
# 3             SkinThickness               0.000162
# 4                   Insulin              -0.000089
# 5                       BMI               0.014413
# 6  DiabetesPedigreeFunction               0.129215
# 7                       Age               0.002100

# %%
yhat = lm.predict(X)
y = df2.Outcome

# %%
SS_Residual = sum((y-yhat)**2)
SS_Total = sum((y-np.mean(y))**2)

# %%
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X.shape[1]-1)
print(r_squared, adjusted_r_squared)
# Out:
# 0.3210031839758233 0.3138464322917739

# %%
#8
